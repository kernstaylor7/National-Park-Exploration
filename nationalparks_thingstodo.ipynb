# %%
import json
import requests
from pprint import pprint
import pandas as pd
import os

# %%
# Configure API request
api_keys= '7b3ckIbue9dRLLchEjkXcDw5avq9dXfp67gjNidl'

# %%
output_data_file = 'output_data/thingstodo.csv'

# %%
parameters={'parkInformation': 'id, parkCode, stateCode'}

# %%
url= 'https://developer.nps.gov/api/v1/thingstodo?id=&api_key=7b3ckIbue9dRLLchEjkXcDw5avq9dXfp67gjNidl'

# %%
headers= {'Content-Type': 'application/json'}

# %%
response=requests.post(url, headers=headers, params=parameters)

# %%
data = requests.get(url).json()
data
# Out:
# {'total': '2362',
#  'limit': '50',
#  'start': '0',
#  'data': [{'id': 'B97DA3F6-96A1-434D-875E-DA3F0489D941',
#    'url': 'https://www.nps.gov/thingstodo/explore-historic-carroll-homestead.htm',
#    'title': 'Explore Historic Carroll Homestead',
#    'shortDescription': 'Head towards the west side of the island to visit an example of 1800s island life at Carroll Homestead, a time capsule of early Euro-american settlement before Mount Desert Island became a tourist destination and Acadia National Park came into being.',
#    'images': [{'url': 'https://www.nps.gov/common/uploads/cropped_image/22FA091B-F54E-D7EA-48C3B4445B328F27.jpg',
#      'credit': 'Emma Forthofer/Friends of Acadia',
#      'altText': 'A grey, wood-shingle building with two chimneys sits in a grassy field with trees in the background',
#      'title': 'Carroll Homestead',
#      'description': '',
#      'caption': 'Explore Carroll Homestead on your own or during a ranger program',
# ...

# %%
np_todo.to_csv("Project_2/todo_data.csv", index=False, header=True)
